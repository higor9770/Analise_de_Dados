# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/202301_NFe_NotaFiscalItem.csv", encoding='ISO-8859-1', sep = ";")

# %%
df1 = pd.DataFrame(data)

# %%
df1.columns # mostrando as colunas
# Out:
# Index(['CHAVE DE ACESSO', 'MODELO', 'SÉRIE', 'NÚMERO', 'NATUREZA DA OPERAÇÃO',
#        'DATA EMISSÃO', 'CPF/CNPJ Emitente', 'RAZÃO SOCIAL EMITENTE',
#        'INSCRIÇÃO ESTADUAL EMITENTE', 'UF EMITENTE', 'MUNICÍPIO EMITENTE',
#        'CNPJ DESTINATÁRIO', 'NOME DESTINATÁRIO', 'UF DESTINATÁRIO',
#        'INDICADOR IE DESTINATÁRIO', 'DESTINO DA OPERAÇÃO', 'CONSUMIDOR FINAL',
#        'PRESENÇA DO COMPRADOR', 'NÚMERO PRODUTO',
#        'DESCRIÇÃO DO PRODUTO/SERVIÇO', 'CÓDIGO NCM/SH',
#        'NCM/SH (TIPO DE PRODUTO)', 'CFOP', 'QUANTIDADE', 'UNIDADE',
#        'VALOR UNITÁRIO', 'VALOR TOTAL'],
#       dtype='object')

# %%
df1.tail(10)
# Out:
#                                      CHAVE DE ACESSO  \
# 397622  35230140774328000180550010000000291105292618
# 397623  35230140774328000180550010000000291105292618
# 397624  35230140774328000180550010000000291105292618
# 397625  35230140774328000180550010000000291105292618
# 397626  35230140774328000180550010000000291105292618
# 397627  35230140774328000180550010000000291105292618
# 397628  35230140774328000180550010000000291105292618
# 397629  35230140774328000180550010000000291105292618
# 397630  35230140774328000180550010000000291105292618
# 397631  43230188587357006019550020000491131000038732
#
#                                                    MODELO  SÉRIE  NÚMERO  \
# 397622  55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...      1      29
# 397623  55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...      1      29
# 397624  55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...      1      29
# 397625  55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...      1      29
# ...

# %%
df1.isnull().sum() # sabendo se há valores nulos
# Out:
# CHAVE DE ACESSO                     0
# MODELO                              0
# SÉRIE                               0
# NÚMERO                              0
# NATUREZA DA OPERAÇÃO                0
# DATA EMISSÃO                        0
# CPF/CNPJ Emitente                   0
# RAZÃO SOCIAL EMITENTE               0
# INSCRIÇÃO ESTADUAL EMITENTE         0
# UF EMITENTE                         0
# MUNICÍPIO EMITENTE                  0
# CNPJ DESTINATÁRIO                   0
# NOME DESTINATÁRIO                   0
# UF DESTINATÁRIO                     0
# INDICADOR IE DESTINATÁRIO           0
# DESTINO DA OPERAÇÃO                 0
# CONSUMIDOR FINAL                    0
# PRESENÇA DO COMPRADOR               0
# NÚMERO PRODUTO                      0
# DESCRIÇÃO DO PRODUTO/SERVIÇO        0
# CÓDIGO NCM/SH                       0
# NCM/SH (TIPO DE PRODUTO)        18010
# CFOP                                0
# QUANTIDADE                          0
# UNIDADE                           587
# ...

# %%
df1.info() # para ver a quantidade de colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397632 entries, 0 to 397631
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   CHAVE DE ACESSO               397632 non-null  object
#  1   MODELO                        397632 non-null  object
#  2   SÉRIE                         397632 non-null  int64
#  3   NÚMERO                        397632 non-null  int64
#  4   NATUREZA DA OPERAÇÃO          397632 non-null  object
#  5   DATA EMISSÃO                  397632 non-null  object
#  6   CPF/CNPJ Emitente             397632 non-null  object
#  7   RAZÃO SOCIAL EMITENTE         397632 non-null  object
#  8   INSCRIÇÃO ESTADUAL EMITENTE   397632 non-null  object
#  9   UF EMITENTE                   397632 non-null  object
#  10  MUNICÍPIO EMITENTE            397632 non-null  object
#  11  CNPJ DESTINATÁRIO             397632 non-null  int64
# ...

# %%
Estados_Destinatirio = df1['UF DESTINATÁRIO'].value_counts()
Estados_Destinatirio
# Out:
# RJ    88079
# DF    86650
# RS    32280
# SP    25799
# MG    25341
# PR    16003
# BA    13128
# MS    11392
# PE    11075
# PA    10518
# RN    10413
# SC     9719
# AM     8851
# GO     6326
# CE     6064
# MT     5779
# PI     4925
# PB     4285
# ES     3756
# RR     3218
# RO     2824
# AL     2744
# MA     2704
# AC     2032
# TO     1300
# SE     1237
# AP     1190
# Name: UF DESTINATÁRIO, dtype: int64

# %%
df1['NÚMERO'].value_counts()
# Out:
# 33740      666
# 1084448    463
# 72         444
# 38117      412
# 37872      407
#           ...
# 499251       1
# 499252       1
# 499253       1
# 499254       1
# 49113        1
# Name: NÚMERO, Length: 61312, dtype: int64

# %%
df1[df1['NÚMERO'] == 16]
# Out:
#                                      CHAVE DE ACESSO  \
# 2       33230134849096000189550010000000161591173139
# 3       33230134849096000189550010000000161591173139
# 4       33230134849096000189550010000000161591173139
# 5       33230134849096000189550010000000161591173139
# 6       33230134849096000189550010000000161591173139
# ...                                              ...
# 383444  13230104613444000153557010000000161673154920
# 390525  43230133992679000100550010000000161378000657
# 390526  43230133992679000100550010000000161378000657
# 390527  43230133992679000100550010000000161378000657
# 396004  25230147504653000171550010000000161727512688
#
#                                                    MODELO  SÉRIE  NÚMERO  \
# 2       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...      1      16
# 3       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...      1      16
# 4       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...      1      16
# ...

# %%
contagem_de_16 = (df1['NÚMERO'] == 16).sum()
contagem_de_16
# Out:
# 218

# %%
df1.drop(["CPF/CNPJ Emitente", "CNPJ DESTINATÁRIO", "INDICADOR IE DESTINATÁRIO", "CFOP", "NCM/SH (TIPO DE PRODUTO)", "CÓDIGO NCM/SH"] , axis=1, inplace=True)
 # exluindo colunas

# %%
df1.columns
# Out:
# Index(['CHAVE DE ACESSO', 'MODELO', 'SÉRIE', 'NÚMERO', 'NATUREZA DA OPERAÇÃO',
#        'DATA EMISSÃO', 'RAZÃO SOCIAL EMITENTE', 'INSCRIÇÃO ESTADUAL EMITENTE',
#        'UF EMITENTE', 'MUNICÍPIO EMITENTE', 'NOME DESTINATÁRIO',
#        'UF DESTINATÁRIO', 'DESTINO DA OPERAÇÃO', 'CONSUMIDOR FINAL',
#        'PRESENÇA DO COMPRADOR', 'NÚMERO PRODUTO',
#        'DESCRIÇÃO DO PRODUTO/SERVIÇO', 'QUANTIDADE', 'UNIDADE',
#        'VALOR UNITÁRIO', 'VALOR TOTAL'],
#       dtype='object')

# %%
df1["CONSUMIDOR FINAL"].unique()
# O Consumidor Final, pode ser uma Pessoa Física ou
# Pessoa Jurídica, apresentada como Destinatária da NF-e ou NFC-e, que está adquirindo
# um produto / mercadoria para seu uso, normalmente, produtos em seu estado final de comercialização,
# como um celular, um notebook, uma mesa, cadeira, televisão, etc.
# Já o Consumidor Normal, que também pode ser Pessoa Física ou Pessoa Jurídica,
# é um tipo de identificação permitida apenas para NF-e, e que normalmente o
# Destinatário é informado como Contribuinte de ICMS. Nessa operação, o produto
# / mercadoria comercializada, está sendo adquirida para compor a fabricação de um
# novo produto, para ser modificada, ou revendida. Nesse caso, o Destinatário dessa NF-e
# não é Consumidor Final porque ele não o está comprando para uso próprio, mas sim
# para tratá-lo e vendê-lo a outra Pessoa.
# Out:
# array(['1 - CONSUMIDOR FINAL', '0 - NORMAL'], dtype=object)
